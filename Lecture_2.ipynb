# %% [markdown]
# # Create sparksession
#
# How to create SparkSession?

# %%
spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("example_spark_session") \
    .config("key", "value") \
    .getOrCreate()

# %%
spark

# %%
print(spark)

# %%
spark.range(5).show()

# %%
spark.sql("SELECT 'SparkSession is working'").display()

# %% [markdown]
# ## Reading CSV File

# %%
 from pyspark.sql import SparkSession
    
spark = SparkSession.builder \
                .appName("example_spark_session") \
                .getOrCreate()

# %%
 df = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .option("sep", ",")        
        .option("mode", "DROPMALFORMED")  
        .csv("/Volumes/workspace/default/omkar_volume/annual-enterprise-survey-2024-financial-year-provisional.csv")
        )
 df.display()

# %%
df.show(20)

# %%
df.collect()

# %% [markdown]
# ## # Create SparkSession with Hive support
# not supported

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
        .appName("HiveExample") \
        .config("spark.sql.warehouse.dir", "/user/hive/warehouse") \
        .config("spark.driver.cores",2)\
        .config("spark.executor.core",3)\
        .enableHiveSupport() \
        .getOrCreate()

# %%
spark.sql("show databases").show()

# %% [markdown]
# ####################1

# %%
# Create a DataFrame from a Python list
data = [1, 2, 3, 4, 5]
df = spark.createDataFrame(
    [(x,) for x in data],
    ["value"]
)

# Multiply each element by 2
df2 = df.withColumn(
    "value_times_2",
    df["value"] * 2
)

# Filter elements > 5
df3 = df2.filter(
    df2["value_times_2"] > 5
)

# Display the result
display(df3)
